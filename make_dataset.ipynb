# %%
# importing libraries
import h5py
import scipy.io as io
import numpy as np
import glob
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter
import scipy
from matplotlib import cm as CM
from PIL import Image
import os
# %matplotlib inline

# %%
# function to create density maps for images
def gaussian_filter_density(gt):
    print (gt.shape)
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(list(zip(np.nonzero(gt)[1], np.nonzero(gt)[0])))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print ('generate density...')
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += gaussian_filter(pt2d, sigma, mode='constant')
    print ('done.')
    return density

# %%
#set the root to the Shanghai dataset you download
root = 'ShanghaiTech'

# %%
#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A/train_data','images')
part_A_test = os.path.join(root,'part_A/test_data','images')
part_B_train = os.path.join(root,'part_B/train_data','images')
part_B_test = os.path.join(root,'part_B/test_data','images')
path_sets = [part_A_train,part_A_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print (img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground-truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground-truth'), 'w') as hf:
        hf['density'] = k
# Out:
# ShanghaiTech\part_A/train_data\images\IMG_1.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_10.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_100.jpg
# (654, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_101.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_102.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_103.jpg
# (400, 400)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_104.jpg
# (405, 540)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_105.jpg
# (632, 990)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_106.jpg
# (675, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_107.jpg
# (517, 800)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_108.jpg
# (767, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_109.jpg
# (681, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_11.jpg
# (686, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_110.jpg
# (498, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_111.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_112.jpg
# (327, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_113.jpg
# (390, 600)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_114.jpg
# (375, 500)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_115.jpg
# (611, 1021)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_116.jpg
# (640, 640)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_117.jpg
# (579, 840)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_118.jpg
# (651, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_119.jpg
# (594, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_12.jpg
# (680, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_120.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_121.jpg
# (373, 561)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_122.jpg
# (787, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_123.jpg
# (774, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_124.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_125.jpg
# (565, 849)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_126.jpg
# (576, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_127.jpg
# (300, 400)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_128.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_129.jpg
# (689, 998)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_13.jpg
# (747, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_130.jpg
# (680, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_131.jpg
# (498, 390)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_132.jpg
# (800, 600)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_133.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_134.jpg
# (1024, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG_135.jpg
# (182, 420)
# generate density...
# done.
# ShanghaiTech\part_A/train_data\images\IMG
 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_49.jpg
# (464, 634)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_5.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_50.jpg
# (1024, 992)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_51.jpg
# (667, 1000)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_52.jpg
# (284, 550)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_53.jpg
# (369, 553)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_54.jpg
# (350, 725)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_55.jpg
# (630, 934)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_56.jpg
# (411, 620)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_57.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_58.jpg
# (706, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_59.jpg
# (350, 860)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_6.jpg
# (687, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_60.jpg
# (599, 900)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_61.jpg
# (398, 598)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_62.jpg
# (480, 624)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_63.jpg
# (655, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_64.jpg
# (443, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_65.jpg
# (400, 682)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_66.jpg
# (1024, 743)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_67.jpg
# (600, 800)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_68.jpg
# (607, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_69.jpg
# (308, 498)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_7.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_70.jpg
# (417, 600)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_71.jpg
# (763, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_72.jpg
# (480, 640)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_73.jpg
# (681, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_74.jpg
# (742, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_75.jpg
# (500, 650)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_76.jpg
# (450, 676)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_77.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_78.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_79.jpg
# (477, 718)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_8.jpg
# (684, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_80.jpg
# (690, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_81.jpg
# (343, 743)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_82.jpg
# (370, 545)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_83.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_84.jpg
# (680, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_85.jpg
# (577, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_86.jpg
# (741, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_87.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_88.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_89.jpg
# (534, 800)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_9.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_90.jpg
# (457, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_91.jpg
# (683, 1024)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_92.jpg
# (540, 833)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_93.jpg
# (299, 450)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_94.jpg
# (276, 460)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_95.jpg
# (234, 350)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_96.jpg
# (334, 540)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_97.jpg
# (669, 1000)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_98.jpg
# (373, 561)
# generate density...
# done.
# ShanghaiTech\part_A/test_data\images\IMG_99.jpg
# (480, 640)
# generate density...
# done.

# %%
#now see a sample from ShanghaiA
plt.imshow(Image.open("ShanghaiTech/part_A/test_data/images/IMG_30.jpg"))

# %%
gt_file = h5py.File("ShanghaiTech/part_A/test_data/images/IMG_30.jpg".replace('.jpg','.h5').replace('images','ground-truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet)

# %%
np.sum(groundtruth)# don't mind this slight variation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.sum(groundtruth)# don't mind this slight variation
#
# NameError: name 'np' is not defined

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print (img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground-truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground-truth'), 'w') as hf:
        hf['density'] = k
# Out:
# ShanghaiTech\part_B/train_data\images\IMG_1.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_10.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_100.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_101.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_102.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_103.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_104.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_105.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_106.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_107.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_108.jpg
# (768, 1024)
# generate density...
# done.
# ShanghaiTech\part_B/train_data\images\IMG_109.jpg
# (768, 1024)
# generate density...
